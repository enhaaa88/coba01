# %% [markdown]
# <a href="https://colab.research.google.com/github/enhaaa88/coba01/blob/main/svm_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
from datetime import date

# %%
tryout = pd.read_csv("tryout.csv")

# %%
tryout.shape
# Out:
# (72, 20)

# %%
tryout.head()
# Out:
#    Rank          NIS                    Nama        Sekolah  \
# 0     1  20307332037      Rizqi Zuhdi Amarta  SMAN 1 PADANG
# 1     2  20307331061  Resti Natalia Chaniago  SMAN 5 PADANG
# 2     3  20307331062        Indah Widia Sari  SMAN 5 PADANG
# 3     4  20307332049                 Mulyadi   MAN 2 PADANG
# 4     5  20307331058          Elfaiza Warsya   SMA DONBOSCO
#
#                        PTN                            Jurusan      PG  \
# 0   UNIVERSITAS GAJAH MADA  BANGUNAN SOSIAL DAN KESEJAHTERAAN  653.11
# 1  UNIVERSITAS GADJAH MADA                            SEJARAH  484.58
# 2    UNIVERSITAS INDONESIA                     SASTRA INGGRIS  481.70
# 3    UNIVERSITAS INDONESIA                   SASTRA INDONESIA  465.99
# 4    UNIVERSITAS INDONESIA           ILMU ADMINISTRASI NEGARA  485.77
#
#    Penalaran Umum  Pemahaman Bacaan & Menulis  Pengetahuan & Pemahaman Umum  \
# 0          709.99                      475.55                        597.82
# ...

# %%
data = tryout.drop(['Rank','NIS','Sekolah','PTN','Jurusan','PG'], axis=1)

# %%
data.head()
# Out:
#                      Nama  Penalaran Umum  Pemahaman Bacaan & Menulis  \
# 0      Rizqi Zuhdi Amarta          709.99                      475.55
# 1  Resti Natalia Chaniago          560.00                      525.00
# 2        Indah Widia Sari          595.00                      525.00
# 3                 Mulyadi          560.00                      525.00
# 4          Elfaiza Warsya          595.00                      560.00
#
#    Pengetahuan & Pemahaman Umum  Pengetahuan Kuantitatif  Bahasa Inggris  \
# 0                        597.82                   658.11          672.36
# 1                        595.00                   595.00          574.00
# 2                        560.00                   560.00          560.00
# 3                        560.00                   525.00          542.50
# 4                        490.00                   560.00          546.00
#
#    Ekonomi  Geografi  Sosiologi  Sejarah  Nilai TPS  Nilai TKA  Skor UTBK  \
# ...

# %%
X = data.drop(['Nama','Status'], axis=1)
y = data['Status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[8 3]
#  [1 3]]
#               precision    recall  f1-score   support
#
#  BELUM LULUS       0.89      0.73      0.80        11
#        LULUS       0.50      0.75      0.60         4
#
#     accuracy                           0.73        15
#    macro avg       0.69      0.74      0.70        15
# weighted avg       0.79      0.73      0.75        15
